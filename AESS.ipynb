# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="IKPdH4AfOgpm69TLHkhC")
project = rf.workspace().project("aess")
model = project.version(2).model

# infer on a local image
print(model.predict("/moon.jpeg", confidence=10, overlap=30).json())

# visualize your prediction
model.predict("/moon.jpeg", confidence=40, overlap=30).save("/prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("/prediction.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
